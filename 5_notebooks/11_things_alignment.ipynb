# %% [markdown]
# # 11 – THINGS-fMRI Alignment Figures
#
#
# Replicate the NSD analyses on the **THINGS-fMRI** dataset. We visualize inter-subject and model–brain RSA, test the power-law relation with vision models, trace hierarchical depth curves, and inspect the 30‑ROI connectivity backbone.

# %% [markdown]
# ## Imports
#
# Load plotting/statistics utilities and project-specific helpers (surface plotting, interpolation, power-law fitting, standardized colorbars/fonts).

# %%
import sys
sys.path.append("..")

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Helper function in module to make the notebook more readable
from convergence.operations import interpolate_alignment_series, unpack_scores
from convergence.plotting import plot_faverage_parcelation
from convergence.figures import setup_matplotlib_fonts, plot_cbar_set
from convergence.power_law import fit_powerlaw_zero_with_bootstrap
from convergence.figures_other_datasets import load_alignment

setup_matplotlib_fonts()

# %% [markdown]
# ## Data paths & validation
#
# Point to THINGS-derived RSA files (subject–subject and subject–model, joined & separated hemispheres). Assert presence to avoid surprises later.

# %%
data_folder = Path("../derivatives")

hcp_filename = data_folder / "metadata" / "hcp.csv"
model_info_filename = data_folder / "metadata" / "models-info.csv"
things_folder = data_folder / "things"

# Dictionary organizing files as
#  [subset=all] x [model|subject] x [joined|separated]
filenames = {
    "all": {
        "subject": {
            "joined": "rsa_things_subject_subject_alignment_joined.parquet",
            "separated": "rsa_things_subject_subject_alignment_separated.parquet",
        },
        "model": {
            "joined": "rsa_things_subject_model_alignment_joined.parquet",
            "separated": "rsa_things_subject_model_alignment_separated.parquet",
        },
    }
}

# Convert the filenames as paths
subset = "all"
for modality in ["model", "subject"]:
    for hemispheres in ["joined", "separated"]:
        filename = things_folder / filenames[subset][modality][hemispheres]
        filenames[subset][modality][hemispheres] = filename
        assert filename.exists(), f"Check {filename.name}"

figure_folder = Path("../figures")
output_folder = figure_folder / "11_things_alignment"
output_folder.mkdir(exist_ok=True)

# %% [markdown]
# ## ROI order (top‑30 set)
#
# Maintain the NSD-derived **connectivity order** (top within-subject reliability) for heatmaps to keep figures comparable across datasets:
#
# `['V1','V2','V3','V4','V8','V3A','V3B','V3CD','VVC','VMV3','VMV2','VMV1','PHA1','PHA2','PHA3','IP0','PGp','DVT','LO3','LO2','PIT','LO1','FFC','PH','TPOJ3','V4t','FST','MST','MT','TPOJ2']`

# %%
connectivity_order = ['V1','V2', 'V3', 'V4', 'V8', 
                      'V3A', 'V3B', 'V3CD', 'VVC', 
                      'VMV3', 'VMV2', 'VMV1', 'PHA1', 'PHA2', 'PHA3', 
                      'IP0', 'PGp', 'DVT', 'LO3', 'LO2', 'PIT', 'LO1', 
                      'FFC', 'PH', 
                      'TPOJ3', 'V4t', 'FST', 'MST', 'MT', 'TPOJ2']

# %% [markdown]
# ## Surface maps
#
# Render **flat cortical maps** (fsaverage) for:
#
# - Intersubject RSA
# - Vision-model RSA
# - Language-model RSA
# - Vision-model “depth” (% of network depth)
#
# for joined vs. separated hemispheres and three views (lateral/medial/ventral).
#
# Metric-specific value ranges:
#
# | Metric               | vmin | vmax |
# |----------------------|-----:|-----:|
# | Inter-subject RSA    | –0.10| 0.10 |
# | Language RSA         | –0.15| 0.15 |
# | Vision RSA           | –0.10| 0.10 |
# | Vision-model depth   |  0.30| 0.70 |
#
# Only regenerate if missing PNGs.

# %%
surface_folder = output_folder / "01_brain_surfaces"
surface_folder.mkdir(exist_ok=True)

vmax = {
    'rsa_intersubject': (-0.08, 0.08),
    'rsa_language': (-0.15, 0.15),
    'rsa_vision': (-0.08, 0.08),
    'depth_vision': (0.3, 0.7),
}
columns = vmax.keys()
views = ["lateral", "medial", "ventral"]
if len(list(surface_folder.glob("01_things_*.png"))) != 0:

    for join_hemispheres in [True]:
        hemispheres = ["lh"] if join_hemispheres else ["lh", "rh"]
        join_name = "joined" if join_hemispheres else "separated"
        df_alignment = load_alignment(filenames=filenames,
                                    hcp_filename=hcp_filename, joined=join_hemispheres)
        for column in columns:
            cmap = "RdBu_r" if column.startswith("rsa") else "PiYG_r"
            for hemisphere in hemispheres:
                brain_name = f"01_things_{column}_{join_name}_{hemisphere}"
                brain = plot_faverage_parcelation(
                    df=df_alignment,
                    value_column=column,
                    hemisphere=hemisphere,
                    default_color='lightgray',
                    default_value=None,
                    cmap=cmap,
                    normalize=vmax[column]
                )
                for view in views:
                    brain.show_view(view)
                    brain.save_image(surface_folder / f"{brain_name}_{view}.png", mode="rgba")
                brain.close()

# %% [markdown]
# ## Quick QA plot
#
# Display a single saved PNG (e.g., `rsa_intersubject – separated – rh – ventral`) to confirm surfaces rendered correctly.

# %%
column = "rsa_intersubject"# "rsa_intersubject", "rsa_language", "rsa_vision", "depth_vision"
join_name = "separated" # "joined", "separated"
hemisphere = "rh" # "lh", "rh"
view = "ventral" # "lateral", "medial", "ventral"
brain_file = surface_folder / f"01_things_{column}_{join_name}_{hemisphere}_{view}.png"
img = plt.imread(brain_file)
fig, ax = plt.subplots()
ax.imshow(img)
ax.set_title(brain_file.name)
ax.axis('off');

# %% [markdown]
# ## Colorbars
#
# Export stand-alone colorbars for manuscript figures, matching the ranges above:
#
# - Inter-subject RSA
# - Vision-model RSA
# - Language-model RSA
# - Vision-model depth (%; PiYG_r, asymmetric)

# %%
# Intersubject
title="Inter-subject alignment (RSA pearson)"
filename = output_folder / "01_colorbar_intersubject.pdf"
plot_cbar_set(title=title, filename=filename, vmin=0, vmax=0.1, locator=0.02)
# Vision models
title="Vision model alignment (RSA pearson)"
filename = output_folder / "01_colorbar_vision.pdf"
plot_cbar_set(title=title, filename=filename, vmin=0, vmax=0.1, locator=0.02)
# Language models
title="Language model alignment (RSA pearson)"
filename = output_folder / "01_colorbar_language.pdf"
plot_cbar_set(title=title, filename=filename, vmin=-0.05, vmax=0.15, locator=0.05)
# Language models
title="Depth vision models (Normalized depth %)"
filename = output_folder / "01_colorbar_vision_depth.pdf"
plot_cbar_set(title=title, filename=filename, vmin=0.3, vmax=0.7, locator=0.05, cmap="PiYG_r", simmetric=False)

# %% [markdown]
# ## Power-law relation (ROI scatter)
#
# Scatter **per-ROI** inter-subject RSA vs. vision-model RSA. Fit a **zero-intercept power law**:
#
# $$
# y = a\,x^b
# $$
#
# (using a small constant shift to handle negatives), with 10 000 bootstrap samples for 95 % CI.
# Annotate legend with \(a, b, R^2\). Points colored by HCP area.

# %%
nsd_folder = data_folder / "nsd"
intersubject_shift1_joined_filename = nsd_folder / "rsa_subject_subject_alignment_shift_1_joined.parquet"
df_nsd = pd.read_parquet(intersubject_shift1_joined_filename)
df_nsd = df_nsd.query("subject_i != subject_j and roi_x == roi_y").groupby(["roi_x"]).similarity.mean().reset_index()
df_nsd = df_nsd.rename(columns={"similarity": "similarity_is_nsd", "roi_x": "roi"})
df_nsd

df_alignment = load_alignment(filenames=filenames, hcp_filename=hcp_filename,joined=True)
df_alignment = df_alignment.merge(df_nsd, on="roi")


x = "rsa_intersubject" # "rsa_intersubject", "rsa_language", "rsa_vision", "similarity_is_nsd"
y = "rsa_vision" # "rsa_intersubject", "rsa_language", "rsa_vision", "similarity_is_nsd"
xlabel = "Inter-subject alignment THINGS (RSA pearson)"
ylabel = "Vision Model - Brain (RSA pearson)"
add_fit = True
x_value = df_alignment[x].to_numpy()
y_value = df_alignment[y].to_numpy()

# To avoid adjust a log-model with negative values. After reversed
x_min = df_alignment[x].min() - 0.0001
y_min = df_alignment[y].min() - 0.0001

# Adjust the power-law
x_fit, y_fit, y_lower, y_upper, r_squared, params = fit_powerlaw_zero_with_bootstrap(
    x_value - x_min, y_value - y_min, n_boot=10000)


fig, ax = plt.subplots(1, 1, figsize=(6, 4))

if add_fit:
    legend = f"$y={params[0]:.2f}x^{{{params[1]:.2f}}}$ ($R^2={r_squared:.2f}$)"
    ax.plot(x_fit+x_min, y_fit+y_min, color="maroon", zorder=-10, label=legend)
    ax.fill_between(x_fit+x_min, y_lower+y_min, y_upper+y_min, color="maroon", alpha=0.1, zorder=-10, label="95% CI")
    ax.legend()

# Add the palette used in the rest of the paper coloured based on anatomical regions
palette = df_alignment.set_index("name").area_color.to_dict()
sns.scatterplot(
    data=df_alignment,
    x=x,
    y=y,
    ax=ax,
    hue="name",
    palette=palette,
    legend=False
)
ax.set_xlabel(xlabel)
ax.set_ylabel(ylabel)
sns.despine(ax=ax)

# Annotate parcel names
for _, row in df_alignment.iterrows():
    if row[x] > 0.02 or row[y] > 0.02:
        ax.text(row[x], row[y], row["name"], fontsize=8)

output_file =  f"02_scatter_comparison_{x}_{y}_things.svg"
fig.savefig(output_folder / output_file, transparent=True, bbox_inches="tight")

# %% [markdown]
# ## Layerwise hierarchical curves
#
# 1. Aggregate model RSA per ROI & layer (mean over subjects).
# 2. Interpolate to a uniform depth axis ([0,1]).

# %%
filename = filenames["all"]["model"]["joined"]
df_models = pd.read_parquet(filename)
df_models = df_models.groupby(["subject", "model", "roi", "layer"]).similarity.mean().reset_index()
df_models["max_layer"] = df_models.groupby("model")["layer"].transform("max")
df_models["depth"] = df_models["layer"] / df_models["max_layer"]
max_layer = 41

df_models = df_models.rename(columns={"similarity": "score"})
df_interpolated = interpolate_alignment_series(df_models, groups=["subject", "roi", "model"])
df_interpolated = unpack_scores(df_interpolated)


df_interpolated["modality"] = df_interpolated["model"].str.startswith("vit").map({True: "Vision", False: "Language"})

df_interpolated = df_interpolated.groupby(["modality", "subject", "roi", "layer"]).score.mean().reset_index()
df_interpolated["depth"] = df_interpolated["layer"] / (max_layer - 1)

hcp = pd.read_csv(hcp_filename)

df_interpolated = df_interpolated.merge(hcp[["roi", "name", "area_id", "area_color", "area"]], on="roi", how="inner")

# %% [markdown]
# 3. Plot **Vision** and **Language** models separately for key ROIs:
#
#    - Early Visual: V1, V2
#    - Ventral Hub: VMV2, PHA1
#    - LOTC Hub: MST, TPOJ2

# %%
# Plot the main areas
roi_names = ["V1", "V2", "VMV2", "PHA1", "MST", "TPOJ2"]
palette = hcp.query("name in @roi_names and roi <= 180").set_index("name").area_color.to_dict()
dashes={"V1": (None, None), "V2": (4, 2), "VMV2": (1, 1), "PHA1": (2, 2), "MST": (4, 2), "TPOJ2": (5, 2, 1, 2)}

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

for ax , modality in zip (axes, ("Vision", "Language")):
    data = df_interpolated.query("modality == @ modality and name in @roi_names")
    sns.lineplot(data=data, hue="name", x="depth", y="score", hue_order=roi_names, errorbar='se', style="name", palette=palette, ax=ax, dashes=dashes)
    ax.legend(title="", ncol=3)
    ax.set_xlim(0, 1)
    sns.despine(ax=ax)
    ax.set_xlabel(f"{modality} DNN depth (%)")
    ax.set_ylabel("Model - Brain (RSA)")
    ax.set_title(f"{modality} models (THINGS)")
    ax.set_ylim(-0.06, 0.12)

axes[1].legend_.remove()

output_filename = f"03_hierarchical_curves_things.pdf"
fig.savefig(output_folder / output_filename, bbox_inches="tight", transparent=True)

# %% [markdown]
# ## Connectivity matrix (top‑30 ROIs)
#
# Average inter-subject RSA across subject pairs → pivot to a 30×30 ROI matrix using `connectivity_order`.
# Plot a centered RdBu_r heatmap (no colorbar; exported separately) to examine whether THINGS preserves the two-stream (visual vs. LOTC) structure observed in NSD/BOLD5000.

# %%
cmap = "RdBu_r"
filename = filenames["all"]["subject"]["joined"]
df_subject = pd.read_parquet(filename)
df_subject = df_subject.groupby(["roi_x", "roi_y"]).similarity.mean().reset_index()
hcp = pd.read_csv(hcp_filename)
hcp = hcp[["roi", "name"]]
df_subject = df_subject.merge(hcp, left_on="roi_x", right_on="roi", how="left", suffixes=("", "_x"))
df_subject = df_subject.rename(columns={"name": "name_x"}).drop(columns=["roi"])
df_subject = df_subject.merge(hcp, left_on="roi_y", right_on="roi", how="left", suffixes=("", "_y"))
df_subject = df_subject.rename(columns={"name": "name_y"}).drop(columns=["roi_y"])
df_subject_selected = df_subject.query("name_x in @connectivity_order and name_y in @connectivity_order").copy()
df_connectivity = df_subject_selected.copy().rename(columns={"roi": "roi_y"})
# pivot
df_subject_selected = df_subject_selected.pivot(index="name_x", columns="name_y", values="similarity")
df_subject_selected = df_subject_selected.loc[connectivity_order, connectivity_order]

fig, ax = plt.subplots(figsize=(7, 7))
vmax = round(float(df_subject_selected.max().max()), 2)
vmax = 0.08
sns.heatmap(data=df_subject_selected, vmin=-vmax, vmax=vmax, center=0, cmap=cmap, square=True, cbar=False,
            xticklabels=df_subject_selected.columns,
            yticklabels=df_subject_selected.index, ax=ax)
ax.set_xlabel("")
ax.set_ylabel("")
output_filename = f"04_rsa_things_subject_heatmap_{vmax:.2f}.pdf"
fig.savefig(output_folder / output_filename, bbox_inches="tight", transparent=True)

# Colorbar for the connectivity
title="Inter-subject alignment"
output_file = "04_colorbar_{vmax:.2f}.pdf"
plot_cbar_set(title=title, filename=output_folder / output_file, vmax=vmax, vmin=0, locator=0.05)

# %%
import numpy as np 
cmap = "RdBu_r"
filename = filenames["all"]["subject"]["joined"]
df_subject = pd.read_parquet(filename)
df_subject = df_subject.groupby(["roi_x", "roi_y"]).similarity.mean().reset_index()
hcp = pd.read_csv(hcp_filename)
hcp = hcp[["roi", "name"]]
df_subject = df_subject.merge(hcp, left_on="roi_x", right_on="roi", how="left", suffixes=("", "_x"))
df_subject = df_subject.rename(columns={"name": "name_x"}).drop(columns=["roi"])
df_subject = df_subject.merge(hcp, left_on="roi_y", right_on="roi", how="left", suffixes=("", "_y"))
df_subject = df_subject.rename(columns={"name": "name_y"}).drop(columns=["roi_y"])
df_subject_selected = df_subject.query("name_x in @connectivity_order and name_y in @connectivity_order").copy()
df_self = df_subject.query("roi_x == roi")[["roi_x", "roi", "similarity"]]
df_subject_selected = df_subject_selected.merge(
    df_self[["roi", "similarity"]].rename(columns={"similarity": "self_similarity"}), on="roi"
)
df_subject_selected = df_subject_selected.merge(
    df_self[["roi_x", "similarity"]].rename(columns={"similarity": "self_similarity_x"}), on="roi_x"
                                                )

df_subject_selected["similarity_normalized"] = df_subject_selected["similarity"] / (
    np.sqrt(df_subject_selected["self_similarity"]**2 +  df_subject_selected["self_similarity_x"]**2)
)

# pivot
df_subject_selected = df_subject_selected.pivot(index="name_x", columns="name_y", values="similarity_normalized")
df_subject_selected = df_subject_selected.loc[connectivity_order, connectivity_order]

fig, ax = plt.subplots(figsize=(7, 7))
vmax = round(float(df_subject_selected.max().max()), 2)
vmax = 1
sns.heatmap(data=df_subject_selected, vmin=-vmax, vmax=vmax, center=0, cmap=cmap, square=True, cbar=False,
            xticklabels=df_subject_selected.columns,
            yticklabels=df_subject_selected.index, ax=ax)
ax.set_xlabel("")
ax.set_ylabel("")
output_filename = f"04_rsa_things_subject_heatmap_{vmax:.2f}.pdf"
#fig.savefig(output_folder / output_filename, bbox_inches="tight", transparent=True)

# Colorbar for the connectivity
title="Inter-subject alignment"
output_file = "04_colorbar_{vmax:.2f}.pdf"
plot_cbar_set(title=title, filename=output_folder / output_file, vmax=vmax, vmin=0, locator=0.05)

# %% [markdown]
# ## Network

# %%
from convergence.figures_utils import process_intersubject_rois


pvalues_filename = nsd_folder / "rsa_pvalues_subject_language_vision.parquet"
models_filename = data_folder / "metadata" / "models-info.csv"
models_alignment_filename = filenames["all"]["model"]["joined"]
subject_alignment_filename = filenames["all"]["subject"]["joined"]

models_info = pd.read_csv(models_filename)
models_info = models_info[["model_name", "modality"]].rename(columns={"model_name": "model"})
df_models = pd.read_parquet(models_alignment_filename)
# df_models = load_filename("models", joined=joined)
df_models = df_models.rename(columns={"similarity": "score"})
df_models = df_models.query("score < 1 and score > -1")  # Not needed. No one is out of bounds
df_models["max_layer"] = df_models.groupby(["model"], observed=True).layer.transform("max")
df_models["depth"] = df_models["layer"] / df_models["max_layer"]
df_models["abs_score"] = df_models["score"].abs()
df_models = df_models.sort_values("abs_score", ascending=False).drop_duplicates(
    ["roi", "model", "subject", "session"], keep="first"
)  # Get the best score for each roi, model, subject, session

df_models = (
    df_models.groupby(["roi", "model", "subject"], observed=True)
    .aggregate({"score": "mean", "depth": "mean"})
    .reset_index()
)
df_models = df_models.merge(models_info, on="model")


df_models = (
    df_models.groupby(["roi", "modality", "subject"])
    .aggregate({"score": "mean", "depth": "mean"})
    .reset_index()
)



df_models_vision = df_models.query("modality == 'vision'")
df_intersubject = pd.read_parquet(subject_alignment_filename)
df_intersubject = process_intersubject_rois(
    df_intersubject, hcp_filename=hcp_filename, top=1000
)
groups = ["roi", "subject"]
df_intersubject = df_intersubject.groupby(groups).score.mean().reset_index()
df_intersubject = df_intersubject.rename(columns={"score": "intersubject_rsa"})

df_models_vision = df_models_vision.rename(
    columns={"score": "vision_rsa", "depth": "vision_depth"}
)
df_models_vision = df_models_vision[groups + ["vision_rsa", "vision_depth"]]
df_comparison = df_intersubject.merge(df_models_vision, on=groups)

p_values = pd.read_parquet(pvalues_filename)
p_values_intersubject = p_values.query("comparison == 'intersubject'")
p_values_intersubject = p_values_intersubject[
    ["roi", "pvalue_fdr_bh", "null_mean", "null_std", "apa_star"]
].rename(
    columns={
        "pvalue_fdr_bh": "intersubject_p_value",
        "null_mean": "intersubject_null_mean",
        "null_std": "intersubject_null_std",
        "apa_star": "intersubject_apa_star",
    }
)
df_comparison = df_comparison.merge(p_values_intersubject, on="roi", how="left")

hcp = pd.read_csv(hcp_filename)
hcp = hcp[["roi", "name", "area_color", "area_id", "area", "mne_name", "roi_order"]]
df_comparison = df_comparison.merge(hcp, on="roi", how="left")

df_pvalues_vision = p_values.query("comparison == 'vision'")[
    ["roi", "pvalue_fdr_bh", "null_mean", "null_std", "apa_star"]
].rename(
    columns={
        "pvalue_fdr_bh": "vision_p_value",
        "null_mean": "vision_null_mean",
        "null_std": "vision_null_std",
        "apa_star": "vision_apa_star",
    }
)
df_comparison_subjects = df_comparison.merge(df_pvalues_vision, on="roi", how="left")
df_comparison_subjects
# Out:
#      roi  subject  intersubject_rsa  vision_rsa  vision_depth  \
# 0      1        1          0.125348    0.040227      0.298029
# 1      1        2          0.130705    0.057600      0.246528
# 2      1        3          0.084644    0.019743      0.349438
# 3      2        1          0.013442    0.035571      0.700643
# 4      2        2          0.012280    0.011235      0.619547
# ..   ...      ...               ...         ...           ...
# 535  179        2          0.000352   -0.000048      0.502859
# 536  179        3         -0.000348   -0.001767      0.561101
# 537  180        1          0.000082    0.000263      0.498325
# 538  180        2          0.000531    0.000867      0.575633
# 539  180        3          0.000004    0.000579      0.495680
#
#      intersubject_p_value  intersubject_null_mean  intersubject_null_std  \
# 0                0.000161            9.465456e-06               0.003569
# ...

# %%
def add_hcp_names(df, hcp_filename, columns=(("roi", "name"), ("roi_x", "name_x"), ("roi_y", "name_y")), hcp_columns=["roi", "name"]):
    hcp = pd.read_csv(hcp_filename)
    hcp = hcp[hcp_columns]
    for roi_col, name_col in columns:
        if roi_col not in df.columns: continue
        hcp_renamed = hcp.rename(columns={"roi": roi_col, "name": name_col})
        df = df.merge(hcp_renamed, on=roi_col, how="left")
    return df

# %%
from scipy.stats import ttest_rel
from statsmodels.stats.multitest import multipletests

#  Only care of depths with max peak with vision models
df_depths = df_comparison_subjects[["roi", "subject", "vision_depth"]].copy()

# Make cartesian product of edges (180 x 180 combinations)
df_edges_x = df_depths[["roi"]].drop_duplicates().rename(columns={"roi": "roi_x"})
df_edges_y = df_edges_x.rename(columns={"roi_x": "roi_y"})
df_edges = df_edges_x.merge(df_edges_y, how="cross")
# Add the depths x subject
df_edges = df_edges.merge(df_depths.rename(columns={"roi": "roi_x", 'vision_depth': 'vision_depth_x'}),
                            on=["roi_x"])
df_edges = df_edges.merge(df_depths.rename(columns={"roi": "roi_y", 'vision_depth': 'vision_depth_y'}),
                            on=["roi_y", "subject"])
df_edges = df_edges.query("roi_x < roi_y").reset_index(drop=True)
# Make a t-test per edge (roi_x, roi_y), the free variable is the subject
df_depths_edges = df_edges.groupby(["roi_x", "roi_y"]).apply(lambda x: ttest_rel(x["vision_depth_x"], x["vision_depth_y"]), include_groups=False)
df_depths_edges = df_depths_edges.reset_index()
df_depths_edges["t_stat"] = df_depths_edges[0].apply(lambda x: x.statistic)
df_depths_edges["p_value"] = df_depths_edges[0].apply(lambda x: x.pvalue)
# Drop the named tuple
df_depths_edges = df_depths_edges.drop(columns=[0])

# Add corrected p-values
_, pval_corrected, _, _ = multipletests(df_depths_edges["p_value"].values, method="fdr_bh")
df_depths_edges["p_corrected"] = pval_corrected

df_depths_edges_2 = df_depths_edges.copy()
# Swap roi_x and roi_y
df_depths_edges_2 = df_depths_edges_2.rename(columns={"roi_x": "roi_y", "roi_y": "roi_x"})

df_depths_edges = pd.concat([df_depths_edges, df_depths_edges_2], ignore_index=True)

# # Add the names of the ROIs
df_depths_edges = add_hcp_names(df_depths_edges, hcp_filename=hcp_filename)


# Add the mean depths to each node
df_depths_mean = df_depths.groupby("roi").vision_depth.mean().reset_index()
df_depths_edges = df_depths_edges.merge(df_depths_mean.rename(columns={"vision_depth": "vision_depth_x", "roi": "roi_x"}), on="roi_x")
df_depths_edges = df_depths_edges.merge(df_depths_mean.rename(columns={"vision_depth": "vision_depth_y", "roi": "roi_y"}), on="roi_y")
hcp = pd.read_csv(hcp_filename)
df_depths_mean = df_depths_mean.merge(hcp[["roi", "name", "area", "area_id", "area_color"]], on="roi")

# Output filename
print("Mean vision depth for each roi (node of network)")
display(df_depths_mean)

print("Contrast of depths between two nodes (edges of network)")
display(df_depths_edges)
# Out:
# Mean vision depth for each roi (node of network)
#      roi  vision_depth   name                        area  area_id area_color
# 0      1      0.297998     V1              Primary Visual        0    #1f77b4
# 1      2      0.620312    MST            MT+ Visual Areas        6    #2ca02c
# 2      3      0.513440     V6               Dorsal Visual        5    #ff9896
# 3      4      0.293253     V2         Early Visual (V2-4)        1    #aec7e8
# 4      5      0.340683     V3         Early Visual (V2-4)        1    #aec7e8
# ..   ...           ...    ...                         ...      ...        ...
# 175  176      0.547923  STSva        Auditory Association       13    #f7b6d2
# 176  177      0.540128   TE1m            Lateral Temporal        4    #d62728
# 177  178      0.540771     PI  Insula & Frontal Operculum       14    #7f7f7f
# 178  179      0.507867  a32pr   Anterior Cingulate & mPFC       18    #17becf
# ...

# %%
import networkx as nx
def iterative_max_spanning_trees(G, num_trees=1):
    all_edges = []
    G_copy = G.copy()
    for _ in range(num_trees):
        T = nx.minimum_spanning_tree(G_copy)
        all_edges.extend(T.edges(data=True))
        G_copy.remove_edges_from(T.edges())
    G_new = nx.Graph()
    G_new.add_edges_from(all_edges)
    return G_new


def build_graph(df_connectivity, hcp_filename, df_depths_mean):
    """Auxiliar function. Takes connectivity table and split in edges and nodes.
    And merges the depth information to the nodes and build the graph using the edges.
    """
    df_connectivity = add_hcp_names(df_connectivity, hcp_filename=hcp_filename)

    # Get node table (self connections) and append depth and area color information
    df_nodes = df_connectivity.query("roi_x == roi_y").copy()
    df_nodes = df_nodes[["roi_x", "similarity"]].rename(columns={"roi_x": "roi"})
    # If df_depths_mean is provided, merge it with the nodes
    df_nodes = df_nodes.merge(df_depths_mean, on="roi")

    # Add the weight to the edges (1 - similarity) and remove self connections
    df_edges = df_connectivity.query("roi_x != roi_y").copy()
    
    df_edges["weight"] = 1 - df_edges.similarity

    # Transform connectivity table to a graph
    G = nx.from_pandas_edgelist(
        df_edges,
        source="name_x",
        target="name_y",
        edge_attr=["similarity", "weight"],
        create_using=nx.Graph(),
    )
    return G, df_nodes, df_edges

# %%
df_depths_edges_2 = df_depths_edges.copy()
df_depths_edges_2 = df_depths_edges_2.query("name_x in @connectivity_order and name_y in @connectivity_order").copy()
p_values = df_depths_edges_2["p_value"].values
# Correct p-values
_, pval_corrected, _, _ = multipletests(p_values, method="fdr_bh")

# %%
df_connectivity.similarity.max()
# Out:
# np.float32(0.113565974)

# %%
import networkx as nx
from convergence.network import efficient_iterative_max_spanning_trees, plot_graph


num_trees = 3 # Number of itterations for the spanning tree
vmax = 0.08 # Maximum value for the colorbar
seed = 2 # Seed for the layout
# or
n_nodes = len(connectivity_order)
output_filename = output_folder / f"rsa_network_intersubject_n_nodes_{n_nodes}_num_trees_{num_trees}_things.svg"
df_connectivity

G, df_nodes, df_edges = build_graph(df_connectivity.drop(columns=["name_x", "name_y"]), hcp_filename=hcp_filename, df_depths_mean=df_depths_mean)
G_spanning = iterative_max_spanning_trees(G, num_trees=num_trees)
layout_adjustments = {"V2": (-2.5, 0)}

fig, ax = plot_graph(
    G=G_spanning,
    df_nodes=df_nodes,
    df_depths_edges=df_depths_edges_2,
    layout_adjustments=layout_adjustments,
    seed=seed,
    iteration_multiplier=0.5,
    vrange_edge=(-0.08, 0.08)
    
)

fig.savefig(output_filename, bbox_inches="tight", transparent=True)
